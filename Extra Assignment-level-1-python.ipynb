# %% [raw]
# Extra Assignment-level-1-python

# %%
PRINT Statment

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
# Get input from user

# %%
Name=input("Enter your institute name? :")
# Out:
# Enter your institute name? : HOPE AI

# %%
# Get multiple inputs from user

# %%
Name=input("Enter your name:")
Age=int(input("Enter your age:"))
School_Namw=input("Enter your school name:")
Degree=input("Enter your drgree:")
# Out:
# Enter your name: Gayathri
# Enter your age: 40
# Enter your school name: NMCMS
# Enter your drgree: B.E CSE

# %%
#Addition of two numbers

# %%
Number1=int(input("Please enter a number 1:"))
Number2=int(input("Please enter number 2:"))
add=Number1+Number2
print("Addition of the numbers are",add)
# Out:
# Please enter a number 1 23
# Please enter number 2 55
# Addition of the numbers are 78

# %%
#Subtraction of two numbers

# %%
Number1=int(input("Please enter a number 1"))
Number2=int(input("Please enter number 2"))
sub=Number1-Number2
print("Subtraction of the numbers are ",sub)
# Out:
# Please enter a number 1 88
# Please enter number 2 34
# Subtraction of the numbers are  54

# %%
 #Multiplication of two numbers

# %%
Number1=int(input("Please enter a number 1"))
Number2=int(input("Please enter number 2"))
mul=Number1*Number2
print("Multiplication of the numbers are ",mul)
# Out:
# Please enter a number 1 23
# Please enter number 2 45
# Multiplication of the numbers are  1035

# %%
#Division of two number

# %%
Number1=int(input("Please enter a number 1"))
Number2=int(input("Please enter number 2"))
div=Number1/Number2
print("Division of the numbers are ",div)
# Out:
# Please enter a number 1 23
# Please enter number 2 5
# Multiplication of the numbers are  4.6

# %%
#Floor division(Double Slash (//) Operator: Floor Division)

# %%
Number1=int(input("Please enter a number 1:"))
Number2=int(input("Please enter number 2:"))
FD=Number1//Number2
print("Floor Division of the numbers are:",FD)
# Out:
# Please enter a number 1 23
# Please enter number 2 4
# Multiplication of the numbers are  5

# %%
#Modulo

# %%
Number1=int(input("Please enter a number 1:"))
Number2=int(input("Please enter number 2:"))
mod=Number1%Number2
print("Modulo of the numbers are:",mod)
# Out:
# Please enter a number 1: 23
# Please enter number 2: 3
# Multiplication of the numbers are: 2

# %%
#Power

# %%
Number1=int(input("Please enter a number 1:"))
Number2=int(input("Please enter number 2:"))
pow=Number1**Number2
print("Modulo of the numbers are:",pow)
# Out:
# Please enter a number 1: 4
# Please enter number 2: 4
# Modulo of the numbers are: 256
