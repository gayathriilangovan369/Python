# %% [raw]
# # print 'CORRECT' if i == 10
# value: 10
# Corret

# %%
num=int(input("Please enter a number"))
if(num==10):
    print("correct")
else:
    print("incorrect")
# Out:
# Please enter a number 10
# correct

# %% [raw]
# write a python program to check whether the entered password is correct as the stored password
# Enter the password: HOPE@123
# Your password is correct

# %%
Password="HOPE@123"
User=input("Please enter password")
if(User==''):
    print("please enter the password")
elif(User==Password):
    print("Your password is correct")
else:
    print("Incorrect password")
# Out:
# Please enter password HOPE@123
# Your password is correct

# %% [raw]
# write a program to check whether the number is postive or not

# %%
Number=int(input("Enter a number"))
if(Number>0):
    print("This is positive number")
elif(Number<0):
    print("This is negative number")
elif(Number==0):
    print("This is zero")
else:
    print()
# Out:
# Enter a number 4
# This is positive number

# %% [raw]
# Write a program to check whether the entered number is divisible by 5 or not

# %%
num=int(input("Please enter a number"))
if(num%5==0):
    print("Yes the number", num,"is divisible by 5")
else:
    print("No the number", num,"is not divisible by 5")
# Out:
# Please enter a number 22
# No the number 22 is not divisible by 5
