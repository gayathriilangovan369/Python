# %%
from multifunctional import multifunction

# %%
multifunction.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multifunction.OddEven()
# Out:
# Enter a number: 23
# 23 is a odd number
# 'odd'

# %%
multifunction.Eligible()
# Out:
# Please enter your gender Male
# Please enter your age 23
# Eligible
# 'eligible'

# %%
multifunction.percentage()
# Out:
# Please enter your mark subject 1 23
# Please enter your mark subject 2 45
# Please enter your mark subject 3 67
# Please enter your mark subject 4 89
# Please enter your mark subject 5 90
# 314
# 62.8

# %%
multifunction.areatriangle()
# Out:
# Calculating Area of Triangle
# Please enter base 23
# please enter height 2
# Base is 23
# Height is 2
# Area of a triangle  23.0
# 'Area'

# %%
multifunction.perimetertriangle()
# Out:
# Calculating perimeter of Triangle
# Please enter height 1 23
# please enter height 2 12
# Please enter base 34
# Height1 is 23
# Height is 12
# Perimeter of a triangle  69
# 'perimeter'
