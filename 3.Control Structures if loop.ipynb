# %%
age=int(input("please enter your age"))
if(age==18):
    print("Adult")
# Out:
# please enter your age 12

# %%
age=int(input("please enter your age"))
if(age<18):
    print("Children")
else:
    print("Adult")
# Out:
# please enter your age 23
# Adult

# %% [raw]
# Write a program to check whether the given input number is divisible by 3 or else
# show a message “Number is not divisible by 3”

# %%
number=int(input("Please enter a number"))
if(number/3==0):
    print("Number is divisible by 3")
else:
    print("Number is not divisible by 3")
# Out:
# Please enter a number 20
# Number is not divisible by 3

# %% [raw]
# Write a program that checks whether the given input is an even number or an
# odd number.

# %%
number=int(input("please enter a number"))
if(number/2==0):
    print("its a even number")
else:
    print("Its odd number")
# Out:
# please enter a number 3
# Its odd

# %% [raw]
# How Ages are Different (Generations)

# %%
Year=int(input("Please enter your birth year"))
if(Year>=2010 and Year<= 2024):
    print("Children of Millennials, born entirely within the 21st century.")
elif(Year>=1995 and Year<=2009):
    print("Digital natives shaped by the internet, climate anxiety, and COVID-19.")
else:
    print("Golden Era")
# Out:
# Please enter your birth year 1967
# Golden Era

# %%
Age=int(input("Please enter your age"))
if(Age<18):
    print("Children")
elif(Age<35):
    print("Adult")
elif(Age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Please enter your age 55
# Citizen

# %% [raw]
# Write a program that prompts the user for their name, and then displays a special
# greeting to that person if their name is the same as yours. If the name entered by the
# user is anything other than your name, your code should not produce any output

# %%
Name=input("please enter your Name")
if(Name=='Gayathri'):
    print("Hello even my name is Gayathri, Welcome!!!!")
# Out:
# please enter your Name Gayathri
# Hello even my name is Gayathri, Welcome!!!!

# %% [raw]
# Write a program that takes a calendar year in YYYY format in a variable. Check &
# notify the user whether it is a leap year or not.

# %%
Year=int(input("Please enter a year in yyyy format"))
if(Year%4==0 and Year%100 != 0) or (Year % 400 == 0):
    print("This is a leap Year")
else:
    print("This is not a leap year")
# Out:
# Please enter a year in yyyy format 2000
# This is a leap Year

# %% [raw]
# Write a Python program that accept two integers and display the larger. Also
# show if the two integers are equal.

# %%
Number1=int(input("Please enter a number"))
Number2=int(input("Please enter another number"))
if(Number1>Number1):
    print(Number1)
elif(Number2>Number1):
    print(Number2)
elif(Number1==Number2):
    print("Numbers are same")
else:
    print()
# Out:
# Please enter a number 45
# Please enter another number 67
# 67

# %% [raw]
# Write a program that takes input a number from user & state whether the
# number is positive, negative or zero.

# %%
Number=int(input("Enter a number"))
if(Number>0):
    print("This is positive number")
elif(Number<0):
    print("This is negative number")
elif(Number==0):
    print("This is zero")
else:
    print()
# Out:
# Enter a number 23
# This is positive number

# %% [raw]
# Write a program that takes time as input from user in 24 hours clock format like:
# 1900 = 7pm. Implement the following case using if, else & else if statements

# %% [raw]
# Name=input("Please enter your name")
# Time=int(input("Please enter the time in HHMM"))
# if(Time>=0000 and Time<1200):
#     print("Good Morning",Name)
# elif(Time>=1200 and Time<=1700):
#     print("Good Afternoon",Name)
# elif(Time>=1700 and Time<=2000):
#     print("Good Evening",Name)
# else:
#     print("Good Night",Name)

# %%
Write a program that
a) Store correct password in a variable.
b) Asks user to enter his/her password
c) Validate the two passwords:
i. Check if user has entered password. If not, then give message “ Please
enter your password”
ii. Check if both passwords are same. If they are same, show message
“Correct! The password you entered matches the original password”.
iii. Show “Incorrect password” otherwise.

# %%
Password="123qwe"
User=input("Please enter password")
if(User==''):
    print("please enter the password")
elif(User==Password):
    print("Correct! The password you entered matches the original password")
else:
    print("Incorrect password")
# Out:
# Please enter password 123qwe
# Correct! The password you entered matches the original password

# %% [raw]
# If the variable age is a value below 18, the value of the variable voteable should be
# "Too young", otherwise the value of voteable should be "Old enough".

# %%
print("Checking vote eligibilit")
age=int(input("Please enter your age"))
if(age<18):
    print("Too young to vote")
else:
    print("Old enough to vote")
# Out:
# Checking vote eligibilit
# Please enter your age 23
# Old enough to vote
